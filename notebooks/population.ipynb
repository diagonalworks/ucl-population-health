# %%
import pandas as pd

# %%
population = pd.read_csv("../output/population-appointments.csv")
population.appointments.hist(bins=50)
# Out:
# <Axes: >

# %%
population[population.condition_dm == 1].appointments.hist(bins=50)
# Out:
# <Axes: >

# %%
population[(population.condition_dm == 1) & (population.condition_copd == 1)].appointments.hist(bins=50)
# Out:
# <Axes: >
